# %%
액셀<-read.csv("res1.csv",header=T);
x=액셀$저항;
n=length(x);
hx=hist(x,breaks=seq(min(x),max(x),by=(max(x)-min(x))/20),right=F);
# Out:
# Plot with title "Histogram of x"

# %%
xcf<-cumsum(hx$counts)
xrf<-hx$counts/n#상대도수
xrcf<-xcf/n; #상대누적도수;
xtable<-cbind(round(hx$mid,3),hx$counts,xcf,xrf,xrcf);

xclass<-paste0('[', round(hx$breaks[-length(hx$breaks)],3),',',round(hx$breaks[-1],3),')');
rownames(xtable)<-xclass;
colnames(xtable)<-c('대푯값','도수','누적도수','상대도수','상대누적도수')
xtable
# Out:
#             대푯값 도수 누적도수 상대도수 상대누적도수
# [4.59,4.66) 4.625   4     4      0.04     0.04
# [4.66,4.73) 4.695   3     7      0.03     0.07
# [4.73,4.8)  4.765  14    21      0.14     0.21
# [4.8,4.87)  4.835   4    25      0.04     0.25
# [4.87,4.94) 4.905  15    40      0.15     0.40
# [4.94,5.01) 4.975  21    61      0.21     0.61
# [5.01,5.08) 5.045  17    78      0.17     0.78
# [5.08,5.15) 5.115  10    88      0.10     0.88
# [5.15,5.22) 5.185   6    94      0.06     0.94
# [5.22,5.29) 5.255   6   100      0.06     1.00

# %%
sort(x)
# Out:
#   [1] 4.59 4.59 4.65 4.65 4.66 4.69 4.69 4.74 4.74 4.75 4.75 4.76 4.77 4.77 4.77
#  [16] 4.77 4.78 4.79 4.79 4.79 4.79 4.81 4.83 4.84 4.85 4.87 4.87 4.88 4.88 4.88
#  [31] 4.89 4.89 4.89 4.89 4.89 4.91 4.91 4.92 4.93 4.93 4.94 4.94 4.94 4.95 4.95
#  [46] 4.95 4.95 4.95 4.95 4.96 4.97 4.97 4.97 4.98 4.98 4.99 4.99 4.99 4.99 4.99
#  [61] 4.99 5.01 5.01 5.01 5.01 5.02 5.03 5.03 5.04 5.05 5.05 5.05 5.07 5.07 5.07
#  [76] 5.07 5.07 5.07 5.08 5.08 5.08 5.08 5.09 5.09 5.10 5.11 5.11 5.14 5.17 5.17
#  [91] 5.18 5.19 5.19 5.21 5.23 5.23 5.25 5.27 5.28 5.29
