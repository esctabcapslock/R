# %%
round(dhyper(0:3,3,7,3),4)
# Out:
# [1] 0.2917 0.5250 0.1750 0.0083

# %%
n=c(10,20,50);
for (j in n){
    f=dhyper(0:30,200*0.2,200*0.8,j)
    plot(f,type='h')
}
# Out:
# plot without title
# plot without title
# plot without title

# %%
dgeom(0,0.1) # 1번실패 1번성공
# Out:
# [1] 0.1

# %%
dgeom(2,0.3*0.4)
# Out:
# [1] 0.092928

# %%
dnbinom(26,5,0.3*0.4)/(0.3*0.4)
# Out:
# [1] 0.2046936
